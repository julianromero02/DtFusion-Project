# %%
import pandas as pd
import matplotlib

# %%
df_weather = pd.read_csv(
    'Weather.csv',
    header=1,
    sep=None,            # let Python sniff ";" or "\t" or ","
    engine='python',
    encoding='utf-16-le'
)
print(df_weather.columns.tolist())
# Out:
# ['Time (LST)', 'Air Temp (°F)', '0.5 m Air Temp (°F)', '1.5 m Air Temp (°F)', '3 m Air Temp (°F)', 'Relative Humidity (%)', 'Precipitation (in)', 'Accumulated Precip (in)', 'Solar Radiation (W/m²)', 'Wind Speed (mph)', 'Wind Direction (°)', 'Wind Gust (mph)', '4" Bare Soil Temp (°F)', '4" Grass Soil Temp (°F)', '2" Soil Temp (°F)', '2" Soil Water Content (%)', '4" Soil Temp (°F)', '4" Soil Water Content (%)', '8" Soil Temp (°F)', '8" Soil Water Content (%)', '20" Soil Temp (°F)', '20" Soil Water Content (%)', 'Inversion Strength', 'Max Inversion', 'Battery Voltage', 'Heat Index (°F)', 'Wind Chill (°F)']

# %%
# You already have df_weather with all the columns
# Just convert the Time column to datetimes:
df_weather['Time (LST)'] = pd.to_datetime(
    df_weather['Time (LST)'],
    infer_datetime_format=True
)

# Read in your labels (assuming this one loads cleanly with parse_dates):
df_labels = pd.read_csv(
    'labels_Juli.csv',
    parse_dates=['Time (LST)']
)

# Merge: keep every weather row, add in only the Path column from labels
df_merged = df_weather.merge(
    df_labels[['Time (LST)', 'Path']],
    on='Time (LST)',
    how='left'
)
print(df_merged.columns.tolist())
print(df_merged.head())
# Out:
# ['Time (LST)', 'Air Temp (°F)', '0.5 m Air Temp (°F)', '1.5 m Air Temp (°F)', '3 m Air Temp (°F)', 'Relative Humidity (%)', 'Precipitation (in)', 'Accumulated Precip (in)', 'Solar Radiation (W/m²)', 'Wind Speed (mph)', 'Wind Direction (°)', 'Wind Gust (mph)', '4" Bare Soil Temp (°F)', '4" Grass Soil Temp (°F)', '2" Soil Temp (°F)', '2" Soil Water Content (%)', '4" Soil Temp (°F)', '4" Soil Water Content (%)', '8" Soil Temp (°F)', '8" Soil Water Content (%)', '20" Soil Temp (°F)', '20" Soil Water Content (%)', 'Inversion Strength', 'Max Inversion', 'Battery Voltage', 'Heat Index (°F)', 'Wind Chill (°F)', 'Path']
#            Time (LST)  Air Temp (°F)  0.5 m Air Temp (°F)  \
# 0 2025-04-27 18:00:00           69.4                 67.1
# 1 2025-04-27 17:30:00           70.0                 67.6
# 2 2025-04-27 17:00:00           69.6                 68.0
# 3 2025-04-27 16:30:00           69.6                 67.8
# 4 2025-04-27 16:00:00           69.3                 68.0
#
#    1.5 m Air Temp (°F)  3 m Air Temp (°F)  Relative Humidity (%)  \
# 0                 67.6               67.1                     31
# 1                 68.7               67.3                     30
# 2                 69.3               67.5                     30
# 3                 68.7               67.1                     31
# 4                 68.9               66.7                     31
#
#    Precipitation (in)  Accumulated Precip (in) Solar Radiation (W/m²)  \
# 0                 0.0                      0.0                  316.0
# 1                 0.0                      0.0                  443.0
# 2                 0.0                      0.0                  547.0
# 3                 0.0                      0.0                  647.0
# 4                 0.0                      0.0                  739.0
#
#    Wind Speed (mph)  ...  8" Soil Temp (°F)  8" Soil Water Content (%)  \
# 0               7.4  ...               57.6                         35
# 1               7.6  ...               57.4                         35
# 2               8.7  ...               57.2                         35
# 3               8.5  ...               57.0                         35
# 4               9.2  ...               56.8                         35
#
#    20" Soil Temp (°F)  20" Soil Water Content (%)  Inversion Strength  \
# 0                54.3                          44                   1
# 1                54.3                          44                   1
# 2                54.3                          44                   1
# 3                54.3                          44                   1
# 4                54.3                          44                   1
#
#    Max Inversion  Battery Voltage  Heat Index (°F)  Wind Chill (°F)  Path
# 0              1               14              NaN              NaN     C
# 1              1               14              NaN              NaN     C
# 2              1               14              NaN              NaN     C
# 3              1               14              NaN              NaN     C
# 4              1               14              NaN              NaN     C
#
# [5 rows x 28 columns]
# /tmp/ipykernel_108219/1951274079.py:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_weather['Time (LST)'] = pd.to_datetime(

# %%
df_merged.describe()
# Out:
#                 Time (LST)  Air Temp (°F)  0.5 m Air Temp (°F)  \
# count                  865     865.000000           865.000000
# mean   2025-04-18 18:00:00      55.222659            54.493988
# min    2025-04-09 18:00:00      26.600000            24.400000
# 25%    2025-04-14 06:00:00      46.800000            46.400000
# 50%    2025-04-18 18:00:00      54.900000            54.500000
# 75%    2025-04-23 06:00:00      63.000000            62.600000
# max    2025-04-27 18:00:00      84.200000            82.800000
# std                    NaN      11.721828            11.884446
#
#        1.5 m Air Temp (°F)  3 m Air Temp (°F)  Relative Humidity (%)  \
# count           865.000000         865.000000             865.000000
# mean             54.836416          55.019769              62.727168
# min              25.700000          28.000000              23.000000
# 25%              46.600000          46.600000              46.000000
# 50%              54.500000          54.500000              64.000000
# 75%              63.000000          63.000000              81.000000
# max              82.900000          82.400000              95.000000
# std              11.751555          11.406986              20.483609
#
#        Precipitation (in)  Accumulated Precip (in)  Wind Speed (mph)  \
# count          865.000000               865.000000        865.000000
# mean             0.001364                 0.001364          8.313295
# min              0.000000                 0.000000          0.000000
# 25%              0.000000                 0.000000          4.000000
# 50%              0.000000                 0.000000          7.200000
# 75%              0.000000                 0.000000         12.300000
# max              0.260000                 0.260000         24.400000
# std              0.012152                 0.012152          5.267932
#
#        Wind Direction (°)  ...  4" Soil Water Content (%)  8" Soil Temp (°F)  \
# count          865.000000  ...                 865.000000         865.000000
# mean           174.314451  ...                  39.745665          53.218497
# min              0.000000  ...                  33.000000          46.200000
# 25%             99.000000  ...                  38.000000          50.200000
# 50%            162.000000  ...                  39.000000          52.900000
# 75%            266.000000  ...                  42.000000          56.300000
# max            359.000000  ...                  43.000000          60.300000
# std            102.780862  ...                   1.775621           3.903356
#
#        8" Soil Water Content (%)  20" Soil Temp (°F)  \
# count                 865.000000          865.000000
# mean                   36.991908           50.135145
# min                    32.000000           46.200000
# 25%                    36.000000           47.800000
# 50%                    37.000000           49.100000
# 75%                    38.000000           52.200000
# max                    38.000000           54.900000
# std                     0.839521            2.717457
#
#        20" Soil Water Content (%)  Inversion Strength  Max Inversion  \
# count                  865.000000          865.000000     865.000000
# mean                    44.058960            0.965318       0.850867
# min                     39.000000            0.000000      -1.000000
# 25%                     44.000000            0.000000       0.000000
# 50%                     44.000000            0.000000       0.000000
# 75%                     44.000000            1.000000       1.000000
# max                     45.000000            8.000000       8.000000
# std                      0.300449            1.451755       1.558936
#
#        Battery Voltage  Heat Index (°F)  Wind Chill (°F)
# count       865.000000         16.00000       206.000000
# mean         13.638150         80.71875        39.850000
# min          13.000000         79.40000        27.600000
# 25%          13.000000         80.15000        36.225000
# 50%          14.000000         81.05000        40.100000
# 75%          14.000000         81.32500        43.375000
# max          14.000000         81.70000        49.600000
# std           0.480814          0.75650         4.899196
#
# [8 rows x 26 columns]

# %%
df_merged['Path'].value_counts().plot(
    kind='bar',
    title='Number of Weather Records per Path'
)
# Out:
# <Axes: title={'center': 'Number of Weather Records per Path'}, xlabel='Path'>

# %%
df_merged.to_csv(
    'Weather_with_labels.csv',
    index=False,
    encoding='utf-8'
)
